# %%
#https://sourceforge.net/projects/swig/files/swigwin/swigwin-4.0.2/swigwin-4.0.2.zip/download?use_mirror=ixpeering

# %% [markdown]
# # 1. Import Dependencies

# %%
import gym 
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 
import numpy as np
import random
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Types of Spaces

# %%
Discrete(3).sample()
# Out:
# 0

# %%
Box(0,1,shape=(3,3)).sample()
# Out:
# array([[0.49781933, 0.3406956 , 0.536787  ],
#        [0.9906441 , 0.11294025, 0.92704916],
#        [0.5587072 , 0.47451192, 0.55221   ]], dtype=float32)

# %%
Box(0,255,shape=(3,3), dtype=int).sample()
# Out:
# array([[178,   5, 199],
#        [ 30,  32,  68],
#        [ 49, 111, 139]])

# %%
Tuple((Discrete(2), Box(0,100, shape=(1,)))).sample()
# Out:
# (1, array([80.25087], dtype=float32))

# %%
Dict({'height':Discrete(2), "speed":Box(0,100, shape=(1,))}).sample()
# Out:
# OrderedDict([('height', 0), ('speed', array([17.396807], dtype=float32))])

# %%
MultiBinary(4).sample()
# Out:
# array([1, 0, 1, 1], dtype=int8)

# %%
MultiDiscrete([5,2,2]).sample()
# Out:
# array([4, 0, 1], dtype=int64)

# %% [markdown]
# # 3. Building an Environment

# %%
class ShowerEnv(Env):
    def __init__(self):
        # Actions we can take, down, stay, up
        self.action_space = Discrete(3)
        # Temperature array
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
        # Set start temp
        self.state = 38 + random.randint(-3,3)
        # Set shower length
        self.shower_length = 60
        
    def step(self, action):
        # Apply action
        # 0 -1 = -1 temperature
        # 1 -1 = 0 
        # 2 -1 = 1 temperature 
        self.state += action -1 
        # Reduce shower length by 1 second
        self.shower_length -= 1 
        
        # Calculate reward
        if self.state >=37 and self.state <=39: 
            reward =1 
        else: 
            reward = -1 
        
        # Check if shower is done
        if self.shower_length <= 0: 
            done = True
        else:
            done = False
        
        # Apply temperature noise
        #self.state += random.randint(-1,1)
        # Set placeholder for info
        info = {}
        
        # Return step information
        return self.state, reward, done, info

    def render(self, mode=None):
        # Implement viz
        pass
    
    def reset(self):
        # Reset shower temperature
        self.state = np.array([38 + random.randint(-3,3)]).astype(float)
        # Reset shower time
        self.shower_length = 60 
        return self.state

# %%
env=ShowerEnv()
# Out:
# C:\Users\Andrew\anaconda3\lib\site-packages\gym\spaces\box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(

# %%
env.observation_space.sample()
# Out:
# array([0.38186643], dtype=float32)

# %%
env.reset()
# Out:
# array([40.])

# %%
from stable_baselines3.common.env_checker import check_env

# %%
check_env(env, warn=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-39-3f908dd80954> in <module>
# ----> 1 check_env(env, warn=True)
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\env_checker.py in check_env(env, warn, skip_render_check)
#     300
#     301     # ============ Check the returned values ===============
# --> 302     _check_returned_values(env, observation_space, action_space)
#     303
#     304     # ==== Check the render method and the declared render modes ====
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\env_checker.py in _check_returned_values(env, observation_space, action_space)
#     157                 raise AssertionError(f"Error while checking key={key}: " + str(e)) from e
#     158     else:
# --> 159         _check_obs(obs, observation_space, "reset")
#     160
#     161     # Sample a random action
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\env_checker.py in _check_obs(obs, observation_space, method_name)
#     110         assert isinstance(obs, np.ndarray), f"The observation returned by `{method_name}()` method must be a numpy array"
#     111
# --> 112     assert observation_space.contains(
#     113         obs
#     114     ), f"The observation returned by the `{method_name}()` method does not match the given observation space"
#
# AssertionError: The observation returned by the `reset()` method does not match the given observation space

# %% [markdown]
# # 4. Test Environment

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:-42
# Episode:2 Score:-60
# Episode:3 Score:-30
# Episode:4 Score:16
# Episode:5 Score:-26

# %%
env.close()

# %% [markdown]
# # 5. Train Model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=400000)
# Out:
# Logging to Training\Logs\PPO_5
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | -31.1    |
# | time/              |          |
# |    fps             | 509      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -28.3       |
# | time/                   |             |
# |    fps                  | 760         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008984437 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.000158    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.9        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00359    |
# |    value_loss           | 52.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -28.2       |
# | time/                   |             |
# |    fps                  | 907         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013170682 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00122    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 59.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -29.7       |
# | time/                   |             |
# |    fps                  | 1005        |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008078612 |
# |    clip_fraction        | 0.0512      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00104    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00344    |
# |    value_loss           | 55.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -31.2       |
# | time/                   |             |
# |    fps                  | 1074        |
# |    iterations           | 5           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007483052 |
# |    clip_fraction        | 0.0694      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.000173    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00813    |
# |    value_loss           | 68          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -28.7       |
# | time/                   |             |
# |    fps                  | 1128        |
# |    iterations           | 6           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006315235 |
# |    clip_fraction        | 0.0225      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00011    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.7        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.000457   |
# |    value_loss           | 74.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -26.4        |
# | time/                   |              |
# |    fps                  | 1171         |
# |    iterations           | 7            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0065915007 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 9.19e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.1         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0027      |
# |    value_loss           | 81           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -27.9       |
# | time/                   |             |
# |    fps                  | 1199        |
# |    iterations           | 8           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008103894 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0032     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36          |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00309    |
# |    value_loss           | 69.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -26         |
# | time/                   |             |
# |    fps                  | 1226        |
# |    iterations           | 9           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013459656 |
# |    clip_fraction        | 0.0784      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 4.53e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.4        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00488    |
# |    value_loss           | 64.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -23         |
# | time/                   |             |
# |    fps                  | 1251        |
# |    iterations           | 10          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.017106846 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -5.52e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35          |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 81.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -22.6       |
# | time/                   |             |
# |    fps                  | 1267        |
# |    iterations           | 11          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006362684 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -0.000551   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.3        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00225    |
# |    value_loss           | 76.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -25.3       |
# | time/                   |             |
# |    fps                  | 1278        |
# |    iterations           | 12          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008320276 |
# |    clip_fraction        | 0.0482      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.928      |
# |    explained_variance   | -7.96e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.2        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00281    |
# |    value_loss           | 74.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -24.5        |
# | time/                   |              |
# |    fps                  | 1285         |
# |    iterations           | 13           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0061543295 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.924       |
# |    explained_variance   | -1.9e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35           |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 78.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -20.3        |
# | time/                   |              |
# |    fps                  | 1295         |
# |    iterations           | 14           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0040361867 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.906       |
# |    explained_variance   | -6.47e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.6         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | 7.17e-05     |
# |    value_loss           | 83.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -20.6        |
# | time/                   |              |
# |    fps                  | 1308         |
# |    iterations           | 15           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0064742165 |
# |    clip_fraction        | 0.0711       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.901       |
# |    explained_variance   | -0.000666    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.4         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00585     |
# |    value_loss           | 86.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -17.6        |
# | time/                   |              |
# |    fps                  | 1319         |
# |    iterations           | 16           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0075074984 |
# |    clip_fraction        | 0.0622       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.903       |
# |    explained_variance   | 0.00196      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.1         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00413     |
# |    value_loss           | 75.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -16.6        |
# | time/                   |              |
# |    fps                  | 1329         |
# |    iterations           | 17           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0022007762 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.918       |
# |    explained_variance   | -0.00133     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41           |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000172    |
# |    value_loss           | 86           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -14.3        |
# | time/                   |              |
# |    fps                  | 1337         |
# |    iterations           | 18           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0044080485 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.918       |
# |    explained_variance   | 0.000288     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.9         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 85.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -14.3       |
# | time/                   |             |
# |    fps                  | 1344        |
# |    iterations           | 19          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004842396 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.861      |
# |    explained_variance   | -0.00107    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.7        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00694    |
# |    value_loss           | 78.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -13.3        |
# | time/                   |              |
# |    fps                  | 1352         |
# |    iterations           | 20           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0037190702 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.875       |
# |    explained_variance   | 0.0208       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.4         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 87.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -14.1        |
# | time/                   |              |
# |    fps                  | 1358         |
# |    iterations           | 21           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0032677683 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.856       |
# |    explained_variance   | 0.0052       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.8         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 76           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -14.6        |
# | time/                   |              |
# |    fps                  | 1360         |
# |    iterations           | 22           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0064341123 |
# |    clip_fraction        | 0.0431       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.832       |
# |    explained_variance   | -0.00991     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.8         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00147     |
# |    value_loss           | 66.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -14.6       |
# | time/                   |             |
# |    fps                  | 1364        |
# |    iterations           | 23          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.003789784 |
# |    clip_fraction        | 0.0428      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.78       |
# |    explained_variance   | 0.00451     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.1        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 81.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -10          |
# | time/                   |              |
# |    fps                  | 1370         |
# |    iterations           | 24           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0028766126 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.745       |
# |    explained_variance   | 0.0115       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.8         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000858    |
# |    value_loss           | 86.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -8.48        |
# | time/                   |              |
# |    fps                  | 1374         |
# |    iterations           | 25           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0026759163 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.728       |
# |    explained_variance   | 0.0257       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.7         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00164     |
# |    value_loss           | 89.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -8.86       |
# | time/                   |             |
# |    fps                  | 1377        |
# |    iterations           | 26          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.002684481 |
# |    clip_fraction        | 0.023       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.0255     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.7        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.000887    |
# |    value_loss           | 88.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -12.5       |
# | time/                   |             |
# |    fps                  | 1378        |
# |    iterations           | 27          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.002941062 |
# |    clip_fraction        | 0.0631      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.7        |
# |    explained_variance   | 0.00651     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.7        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00349    |
# |    value_loss           | 84.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -10.6        |
# | time/                   |              |
# |    fps                  | 1381         |
# |    iterations           | 28           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0054138447 |
# |    clip_fraction        | 0.0821       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.676       |
# |    explained_variance   | -0.0634      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.5         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00415     |
# |    value_loss           | 70.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -3.88       |
# | time/                   |             |
# |    fps                  | 1383        |
# |    iterations           | 29          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.001826628 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.000118    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.2        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.000905   |
# |    value_loss           | 86.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -0.38        |
# | time/                   |              |
# |    fps                  | 1387         |
# |    iterations           | 30           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0039981985 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.626       |
# |    explained_variance   | 0.000161     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.9         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 99.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 2.92         |
# | time/                   |              |
# |    fps                  | 1390         |
# |    iterations           | 31           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0021995537 |
# |    clip_fraction        | 0.0451       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.62        |
# |    explained_variance   | 0.000272     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43.1         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 93.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 2.32         |
# | time/                   |              |
# |    fps                  | 1393         |
# |    iterations           | 32           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0034783059 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.623       |
# |    explained_variance   | -0.000637    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.6         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 88.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 9            |
# | time/                   |              |
# |    fps                  | 1394         |
# |    iterations           | 33           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0041366373 |
# |    clip_fraction        | 0.0895       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.607       |
# |    explained_variance   | -0.000738    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47           |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00319     |
# |    value_loss           | 96           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 6.04         |
# | time/                   |              |
# |    fps                  | 1395         |
# |    iterations           | 34           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0026773878 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.579       |
# |    explained_variance   | 0.000789     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.5         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | 0.000911     |
# |    value_loss           | 84.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 9.02        |
# | time/                   |             |
# |    fps                  | 1397        |
# |    iterations           | 35          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.006065847 |
# |    clip_fraction        | 0.0731      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.601      |
# |    explained_variance   | 0.00438     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.7        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00445    |
# |    value_loss           | 94.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 11.4         |
# | time/                   |              |
# |    fps                  | 1398         |
# |    iterations           | 36           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0049680015 |
# |    clip_fraction        | 0.0724       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.606       |
# |    explained_variance   | 0.0063       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.5         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 75.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 13.7        |
# | time/                   |             |
# |    fps                  | 1400        |
# |    iterations           | 37          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.006517378 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.0112      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.6        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00143    |
# |    value_loss           | 72.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 13.4        |
# | time/                   |             |
# |    fps                  | 1403        |
# |    iterations           | 38          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.012127792 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.58       |
# |    explained_variance   | -0.0301     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.4        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00585    |
# |    value_loss           | 88.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 1405        |
# |    iterations           | 39          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.005785696 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.641      |
# |    explained_variance   | 0.0162      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.4        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00538    |
# |    value_loss           | 76.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 24.5         |
# | time/                   |              |
# |    fps                  | 1408         |
# |    iterations           | 40           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0052119987 |
# |    clip_fraction        | 0.0616       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.606       |
# |    explained_variance   | -0.0262      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.3         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 59.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 26.3        |
# | time/                   |             |
# |    fps                  | 1410        |
# |    iterations           | 41          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.009285607 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.619      |
# |    explained_variance   | 0.000218    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.2        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.000403    |
# |    value_loss           | 68.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 26.8        |
# | time/                   |             |
# |    fps                  | 1412        |
# |    iterations           | 42          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.019652927 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.00141     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.9        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00589    |
# |    value_loss           | 75.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 30.4        |
# | time/                   |             |
# |    fps                  | 1414        |
# |    iterations           | 43          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.005001986 |
# |    clip_fraction        | 0.0944      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | -0.0328     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.8        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.000547   |
# |    value_loss           | 64.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 37.6         |
# | time/                   |              |
# |    fps                  | 1416         |
# |    iterations           | 44           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0056194626 |
# |    clip_fraction        | 0.0765       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.557       |
# |    explained_variance   | -8.58e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.3         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 0.00257      |
# |    value_loss           | 70.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 39.6         |
# | time/                   |              |
# |    fps                  | 1416         |
# |    iterations           | 45           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0042076427 |
# |    clip_fraction        | 0.0829       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.527       |
# |    explained_variance   | -0.00366     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.3         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000404    |
# |    value_loss           | 70.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 42.7         |
# | time/                   |              |
# |    fps                  | 1416         |
# |    iterations           | 46           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0058222422 |
# |    clip_fraction        | 0.0752       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.528       |
# |    explained_variance   | -0.000201    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.1         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.00241      |
# |    value_loss           | 85.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 40.4        |
# | time/                   |             |
# |    fps                  | 1418        |
# |    iterations           | 47          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.025135007 |
# |    clip_fraction        | 0.0745      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.534      |
# |    explained_variance   | 0.000216    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.4        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00174     |
# |    value_loss           | 75.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41          |
# | time/                   |             |
# |    fps                  | 1421        |
# |    iterations           | 48          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.018997753 |
# |    clip_fraction        | 0.0956      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.55       |
# |    explained_variance   | -0.00042    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.4        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00369    |
# |    value_loss           | 94.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 39.9       |
# | time/                   |            |
# |    fps                  | 1423       |
# |    iterations           | 49         |
# |    time_elapsed         | 70         |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.02586214 |
# |    clip_fraction        | 0.108      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.591     |
# |    explained_variance   | -6.56e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 49         |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.00359    |
# |    value_loss           | 84.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 43.2        |
# | time/                   |             |
# |    fps                  | 1423        |
# |    iterations           | 50          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.014077559 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.55       |
# |    explained_variance   | -2.31e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.3        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.000931   |
# |    value_loss           | 93.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.6        |
# | time/                   |             |
# |    fps                  | 1425        |
# |    iterations           | 51          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.018775795 |
# |    clip_fraction        | 0.0976      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.557      |
# |    explained_variance   | -4.97e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.7        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | 0.00705     |
# |    value_loss           | 85.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 48.5         |
# | time/                   |              |
# |    fps                  | 1427         |
# |    iterations           | 52           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0054405374 |
# |    clip_fraction        | 0.0912       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.528       |
# |    explained_variance   | 2.77e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58           |
# |    n_updates            | 510          |
# |    policy_gradient_loss | 0.00274      |
# |    value_loss           | 95.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 50           |
# | time/                   |              |
# |    fps                  | 1428         |
# |    iterations           | 53           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0038068155 |
# |    clip_fraction        | 0.0899       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.544       |
# |    explained_variance   | -1.88e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.3         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | 0.00598      |
# |    value_loss           | 88.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.1        |
# | time/                   |             |
# |    fps                  | 1430        |
# |    iterations           | 54          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.010091849 |
# |    clip_fraction        | 0.0993      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | 5.48e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.5        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | 0.00823     |
# |    value_loss           | 98.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50.2        |
# | time/                   |             |
# |    fps                  | 1432        |
# |    iterations           | 55          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 112640      |
# ...
# |    value_loss           | 101          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 41.1        |
# | time/                   |             |
# |    fps                  | 1472        |
# |    iterations           | 179         |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 366592      |
# | train/                  |             |
# |    approx_kl            | 0.004605322 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.182      |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.9        |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -0.00562    |
# |    value_loss           | 109         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 38.5        |
# | time/                   |             |
# |    fps                  | 1473        |
# |    iterations           | 180         |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.019578539 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.172      |
# |    explained_variance   | -0.45       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.2        |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | 0.019       |
# |    value_loss           | 101         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 32.3         |
# | time/                   |              |
# |    fps                  | 1473         |
# |    iterations           | 181          |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 370688       |
# | train/                  |              |
# |    approx_kl            | 0.0011380955 |
# |    clip_fraction        | 0.0238       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.113       |
# |    explained_variance   | 0.0262       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.3         |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | 0.00124      |
# |    value_loss           | 136          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 24.8        |
# | time/                   |             |
# |    fps                  | 1473        |
# |    iterations           | 182         |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.035468735 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.168      |
# |    explained_variance   | 0.35        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.4        |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | 0.0274      |
# |    value_loss           | 128         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 24.2          |
# | time/                   |               |
# |    fps                  | 1473          |
# |    iterations           | 183           |
# |    time_elapsed         | 254           |
# |    total_timesteps      | 374784        |
# | train/                  |               |
# |    approx_kl            | 0.00080569996 |
# |    clip_fraction        | 0.00796       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.102        |
# |    explained_variance   | -0.0648       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 48.1          |
# |    n_updates            | 1820          |
# |    policy_gradient_loss | 0.000754      |
# |    value_loss           | 94.1          |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 29.2       |
# | time/                   |            |
# |    fps                  | 1473       |
# |    iterations           | 184        |
# |    time_elapsed         | 255        |
# |    total_timesteps      | 376832     |
# | train/                  |            |
# |    approx_kl            | 0.15992543 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.167     |
# |    explained_variance   | 0.554      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 45.2       |
# |    n_updates            | 1830       |
# |    policy_gradient_loss | -0.00532   |
# |    value_loss           | 90.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 28.9       |
# | time/                   |            |
# |    fps                  | 1473       |
# |    iterations           | 185        |
# |    time_elapsed         | 257        |
# |    total_timesteps      | 378880     |
# | train/                  |            |
# |    approx_kl            | 0.18450716 |
# |    clip_fraction        | 0.179      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.228     |
# |    explained_variance   | -0.492     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 59.6       |
# |    n_updates            | 1840       |
# |    policy_gradient_loss | -0.0283    |
# |    value_loss           | 112        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 26.4       |
# | time/                   |            |
# |    fps                  | 1473       |
# |    iterations           | 186        |
# |    time_elapsed         | 258        |
# |    total_timesteps      | 380928     |
# | train/                  |            |
# |    approx_kl            | 0.08854701 |
# |    clip_fraction        | 0.186      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.22      |
# |    explained_variance   | -0.0669    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 46.4       |
# |    n_updates            | 1850       |
# |    policy_gradient_loss | -0.0241    |
# |    value_loss           | 81.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 20.9        |
# | time/                   |             |
# |    fps                  | 1473        |
# |    iterations           | 187         |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 382976      |
# | train/                  |             |
# |    approx_kl            | 0.042184874 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.154      |
# |    explained_variance   | -0.0353     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 81.7        |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.00188    |
# |    value_loss           | 139         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 17.9       |
# | time/                   |            |
# |    fps                  | 1473       |
# |    iterations           | 188        |
# |    time_elapsed         | 261        |
# |    total_timesteps      | 385024     |
# | train/                  |            |
# |    approx_kl            | 0.12729654 |
# |    clip_fraction        | 0.118      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.185     |
# |    explained_variance   | -0.164     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 46.8       |
# |    n_updates            | 1870       |
# |    policy_gradient_loss | -0.00158   |
# |    value_loss           | 105        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 16.5         |
# | time/                   |              |
# |    fps                  | 1473         |
# |    iterations           | 189          |
# |    time_elapsed         | 262          |
# |    total_timesteps      | 387072       |
# | train/                  |              |
# |    approx_kl            | 0.0077793226 |
# |    clip_fraction        | 0.0978       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.14        |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.6         |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | 0.0124       |
# |    value_loss           | 117          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 19.1       |
# | time/                   |            |
# |    fps                  | 1473       |
# |    iterations           | 190        |
# |    time_elapsed         | 264        |
# |    total_timesteps      | 389120     |
# | train/                  |            |
# |    approx_kl            | 0.12010665 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.187     |
# |    explained_variance   | 0.584      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 61.4       |
# |    n_updates            | 1890       |
# |    policy_gradient_loss | -0.0144    |
# |    value_loss           | 133        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 13.6        |
# | time/                   |             |
# |    fps                  | 1473        |
# |    iterations           | 191         |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.012800582 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.15       |
# |    explained_variance   | -0.627      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.9        |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.000721   |
# |    value_loss           | 91.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -4.74      |
# | time/                   |            |
# |    fps                  | 1473       |
# |    iterations           | 192        |
# |    time_elapsed         | 266        |
# |    total_timesteps      | 393216     |
# | train/                  |            |
# |    approx_kl            | 0.08771701 |
# |    clip_fraction        | 0.0547     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.129     |
# |    explained_variance   | 0.545      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 60.9       |
# |    n_updates            | 1910       |
# |    policy_gradient_loss | -0.00089   |
# |    value_loss           | 121        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -7.88      |
# | time/                   |            |
# |    fps                  | 1474       |
# |    iterations           | 193        |
# |    time_elapsed         | 268        |
# |    total_timesteps      | 395264     |
# | train/                  |            |
# |    approx_kl            | 0.27103215 |
# |    clip_fraction        | 0.544      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.166     |
# |    explained_variance   | 0.209      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.07       |
# |    n_updates            | 1920       |
# |    policy_gradient_loss | 0.148      |
# |    value_loss           | 28.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -0.52       |
# | time/                   |             |
# |    fps                  | 1474        |
# |    iterations           | 194         |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 397312      |
# | train/                  |             |
# |    approx_kl            | 0.053397648 |
# |    clip_fraction        | 0.0456      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.108      |
# |    explained_variance   | 0.327       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.9        |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.00617    |
# |    value_loss           | 103         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 19.3          |
# | time/                   |               |
# |    fps                  | 1474          |
# |    iterations           | 195           |
# |    time_elapsed         | 270           |
# |    total_timesteps      | 399360        |
# | train/                  |               |
# |    approx_kl            | 0.00051075476 |
# |    clip_fraction        | 0.0115        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.103        |
# |    explained_variance   | 0.548         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 39.9          |
# |    n_updates            | 1940          |
# |    policy_gradient_loss | 0.00138       |
# |    value_loss           | 90.7          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 21.9         |
# | time/                   |              |
# |    fps                  | 1474         |
# |    iterations           | 196          |
# |    time_elapsed         | 272          |
# |    total_timesteps      | 401408       |
# | train/                  |              |
# |    approx_kl            | 0.0021087974 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0347      |
# |    explained_variance   | 0.641        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49           |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | -0.000676    |
# |    value_loss           | 104          |
# ------------------------------------------

# %% [markdown]
# # 6. Save Model

# %%
model.save('PPO')

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (24.0, 54.99090833947008)
