# %% [markdown]
# # 1. Import Dependencies

# %%
import gym 
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env
import os

# %%
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# Requirement already satisfied: torch in c:\users\andrew\anaconda3\lib\site-packages (1.13.1)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu116/torchvision-0.14.1%2Bcu116-cp38-cp38-win_amd64.whl (4.8 MB)
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu116/torchaudio-0.13.1%2Bcu116-cp38-cp38-win_amd64.whl (2.3 MB)
# Requirement already satisfied: typing-extensions in c:\users\andrew\anaconda3\lib\site-packages (from torch) (4.4.0)
# Requirement already satisfied: numpy in c:\users\andrew\anaconda3\lib\site-packages (from torchvision) (1.21.4)
# Requirement already satisfied: requests in c:\users\andrew\anaconda3\lib\site-packages (from torchvision) (2.25.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\andrew\anaconda3\lib\site-packages (from torchvision) (8.2.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\andrew\anaconda3\lib\site-packages (from requests->torchvision) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\andrew\anaconda3\lib\site-packages (from requests->torchvision) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\andrew\anaconda3\lib\site-packages (from requests->torchvision) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\andrew\anaconda3\lib\site-packages (from requests->torchvision) (2.10)
# Installing collected packages: torchvision, torchaudio
# Successfully installed torchaudio-0.13.1+cu116 torchvision-0.14.1+cu116

# %% [markdown]
# # 2. Test Environment

# %%
# !pip install atari_py
# Out:
# Collecting atari_py
#   Downloading atari_py-0.2.9-cp38-cp38-win_amd64.whl (1.6 MB)
# Requirement already satisfied: six in c:\users\andrew\anaconda3\lib\site-packages (from atari_py) (1.15.0)
# Requirement already satisfied: numpy in c:\users\andrew\anaconda3\lib\site-packages (from atari_py) (1.21.4)
# Installing collected packages: atari-py
# Successfully installed atari-py-0.2.9

# %%
# !python -m atari_py.import_roms .\ROMS
# Out:
# copying adventure.bin from .\ROMS\Adventure (1980) (Atari, Warren Robinett) (CX2613, CX2613P) (PAL).bin to C:\Users\Andrew\anaconda3\lib\site-packages\atari_py\atari_roms\adventure.bin
# Traceback (most recent call last):
#   File "C:\Users\Andrew\anaconda3\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Andrew\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Andrew\anaconda3\lib\site-packages\atari_py\import_roms.py", line 93, in <module>
#     main()
#   File "C:\Users\Andrew\anaconda3\lib\site-packages\atari_py\import_roms.py", line 89, in main
#     import_roms(args.dirpath)
#   File "C:\Users\Andrew\anaconda3\lib\site-packages\atari_py\import_roms.py", line 74, in import_roms
#     with open(filepath, "rb") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '.\\ROMS\\Adventures of TRON (TRON Joystick) (1983) (M Network - INTV - APh Technological Consulting, Hal Finney, Glenn Hightower, Peter Kaminski) (MT4317) ~.bin'

# %%
environment_name = "Breakout-v0"

# %%
env = gym.make(environment_name, render_mode='human')

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:1.0
# Episode:2 Score:2.0
# Episode:3 Score:1.0
# Episode:4 Score:1.0
# Episode:5 Score:0.0

# %%
env.close()

# %%
env.action_space.sample()
# Out:
# 0

# %%
env.observation_space.sample()
# Out:
# array([[[136, 238, 154],
#         [ 70,  11, 192],
#         [181, 212, 101],
#         ...,
#         [218, 140, 201],
#         [ 21,  32,  71],
#         [187,  20,   3]],
#
#        [[241,  12, 194],
#         [186,  93, 221],
#         [174,   0,  72],
#         ...,
#         [  6,  74, 139],
#         [170, 100,  73],
#         [233,  47, 117]],
#
#        [[163, 121,  34],
#         [107,  14,  12],
#         [152,  13, 237],
#         ...,
#         [123, 132,  13],
#         [ 88, 117,   5],
#         [185, 105, 122]],
#
#        ...,
#
#        [[ 46,  22, 164],
#         [123,  89, 178],
#         [190, 117,  59],
#         ...,
#         [214, 201,  30],
#         [ 17, 148, 244],
#         [ 60,  89,  70]],
#
#        [[148,  59,  22],
#         [190,  46,  97],
#         [ 64, 203, 187],
#         ...,
#         [ 61,  49, 153],
#         [199, 170,  24],
#         [172,  36,  99]],
#
#        [[168, 255, 151],
#         [122, 108, 190],
#         [ 24,  46, 105],
#         ...,
#         [196,  94, 225],
#         [237, 195,  37],
#         [122,  16, 128]]], dtype=uint8)

# %% [markdown]
# # 3. Vectorise Environment and Train Model

# %%
env = make_atari_env('Breakout-v0', n_envs=4, seed=0)

# %%
env = VecFrameStack(env, n_stack=4)

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = A2C("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=2000000)
# Out:
# Logging to Training\Logs\A2C_2
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 300      |
# |    ep_rew_mean        | 1.84     |
# | time/                 |          |
# |    fps                | 278      |
# |    iterations         | 100      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | -0.0403  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.487   |
# |    value_loss         | 0.282    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 308      |
# |    ep_rew_mean        | 2.03     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 200      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -0.00987 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.334   |
# |    value_loss         | 0.603    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 303      |
# |    ep_rew_mean        | 1.97     |
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 300      |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | 0.813    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.00299 |
# |    value_loss         | 0.0354   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 308      |
# |    ep_rew_mean        | 2.08     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 400      |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0.874    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.0888   |
# |    value_loss         | 0.0611   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 305      |
# |    ep_rew_mean        | 2        |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 500      |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | -0.454   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.436   |
# |    value_loss         | 0.274    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 320      |
# |    ep_rew_mean        | 2.24     |
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 600      |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.12    |
# |    explained_variance | 0.959    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.00706  |
# |    value_loss         | 0.00328  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 312      |
# |    ep_rew_mean        | 2.08     |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 700      |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.799   |
# |    explained_variance | 0.942    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.00301 |
# |    value_loss         | 0.0136   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 313      |
# |    ep_rew_mean        | 2.14     |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 800      |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.752   |
# |    explained_variance | 0.98     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.00748 |
# |    value_loss         | 0.0109   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 303      |
# |    ep_rew_mean        | 1.96     |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 900      |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | 0.848    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.0234   |
# |    value_loss         | 0.0352   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 312      |
# |    ep_rew_mean        | 2.15     |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 1000     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.802   |
# |    explained_variance | 0.979    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0456  |
# |    value_loss         | 0.0168   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 316      |
# |    ep_rew_mean        | 2.17     |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 1100     |
# |    time_elapsed       | 83       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.688   |
# |    explained_variance | 0.943    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.106    |
# |    value_loss         | 0.0297   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 322      |
# |    ep_rew_mean        | 2.27     |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 1200     |
# |    time_elapsed       | 91       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.21    |
# |    explained_variance | 0.952    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.109    |
# |    value_loss         | 0.0263   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 332      |
# |    ep_rew_mean        | 2.47     |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 1300     |
# |    time_elapsed       | 99       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.769   |
# |    explained_variance | 0.961    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.0265  |
# |    value_loss         | 0.0331   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 342      |
# |    ep_rew_mean        | 2.67     |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 1400     |
# |    time_elapsed       | 106      |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -1.11    |
# |    explained_variance | 0.927    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.0242  |
# |    value_loss         | 0.0144   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 327      |
# |    ep_rew_mean        | 2.51     |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 1500     |
# |    time_elapsed       | 114      |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.659   |
# |    explained_variance | -5.15    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.0294  |
# |    value_loss         | 0.0124   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 283      |
# |    ep_rew_mean        | 1.79     |
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 1600     |
# |    time_elapsed       | 122      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.089   |
# |    explained_variance | -4.13    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.0122  |
# |    value_loss         | 0.0017   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 251       |
# |    ep_rew_mean        | 1.23      |
# | time/                 |           |
# |    fps                | 260       |
# |    iterations         | 1700      |
# |    time_elapsed       | 130       |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -0.0577   |
# |    explained_variance | -2.67     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -0.000138 |
# |    value_loss         | 0.00355   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 251      |
# |    ep_rew_mean        | 1.27     |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 1800     |
# |    time_elapsed       | 138      |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.296   |
# |    explained_variance | 0.957    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.0279   |
# |    value_loss         | 0.0145   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 269      |
# |    ep_rew_mean        | 1.64     |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 1900     |
# |    time_elapsed       | 146      |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -1.04    |
# |    explained_variance | 0.895    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.0379  |
# |    value_loss         | 0.023    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 280      |
# |    ep_rew_mean        | 1.86     |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 2000     |
# |    time_elapsed       | 154      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.573   |
# |    explained_variance | 0.895    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0403  |
# |    value_loss         | 0.0435   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 308      |
# |    ep_rew_mean        | 2.4      |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 2100     |
# |    time_elapsed       | 161      |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.694   |
# |    explained_variance | 0.353    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | 0.107    |
# |    value_loss         | 0.0815   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 336      |
# |    ep_rew_mean        | 2.87     |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 2200     |
# |    time_elapsed       | 169      |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -0.672   |
# |    explained_variance | -2.48    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.0236  |
# |    value_loss         | 0.0569   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 340      |
# |    ep_rew_mean        | 2.85     |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 2300     |
# |    time_elapsed       | 176      |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -0.426   |
# |    explained_variance | 0.947    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.0792   |
# |    value_loss         | 0.0486   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 363      |
# |    ep_rew_mean        | 3.27     |
# | time/                 |          |
# |    fps                | 260      |
# |    iterations         | 2400     |
# |    time_elapsed       | 184      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -0.651   |
# |    explained_variance | 0.416    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.0345   |
# |    value_loss         | 0.194    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 363      |
# |    ep_rew_mean        | 3.39     |
# | time/                 |          |
# |    fps                | 260      |
# |    iterations         | 2500     |
# |    time_elapsed       | 191      |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -0.384   |
# |    explained_variance | 0.636    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.0625  |
# |    value_loss         | 0.251    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 367      |
# |    ep_rew_mean        | 3.41     |
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 2600     |
# |    time_elapsed       | 198      |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -0.654   |
# |    explained_variance | 0.935    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.109   |
# |    value_loss         | 0.0457   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 412       |
# |    ep_rew_mean        | 4.29      |
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 2700      |
# |    time_elapsed       | 206       |
# |    total_timesteps    | 54000     |
# | train/                |           |
# |    entropy_loss       | -0.315    |
# |    explained_variance | 0.935     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -0.000405 |
# |    value_loss         | 0.0308    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 437      |
# |    ep_rew_mean        | 4.86     |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 2800     |
# |    time_elapsed       | 213      |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -0.443   |
# |    explained_variance | 0.847    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.0461  |
# |    value_loss         | 0.0673   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 452      |
# |    ep_rew_mean        | 5.12     |
# | time/                 |          |
# |    fps                | 262      |
# |    iterations         | 2900     |
# |    time_elapsed       | 220      |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -0.541   |
# |    explained_variance | 0.492    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.0176   |
# |    value_loss         | 0.168    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 455      |
# |    ep_rew_mean        | 5.09     |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 3000     |
# |    time_elapsed       | 227      |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -0.349   |
# |    explained_variance | 0.881    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0273   |
# |    value_loss         | 0.0538   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 463      |
# |    ep_rew_mean        | 5.33     |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 3100     |
# |    time_elapsed       | 234      |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -0.475   |
# |    explained_variance | 0.745    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.00198 |
# |    value_loss         | 0.228    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 466      |
# |    ep_rew_mean        | 5.43     |
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 3200     |
# |    time_elapsed       | 242      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -0.415   |
# |    explained_variance | 0.943    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.0837  |
# |    value_loss         | 0.077    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 476      |
# |    ep_rew_mean        | 5.66     |
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 3300     |
# |    time_elapsed       | 249      |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -0.524   |
# |    explained_variance | 0.479    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.0895   |
# |    value_loss         | 0.197    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 465      |
# |    ep_rew_mean        | 5.45     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 3400     |
# |    time_elapsed       | 256      |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -0.42    |
# |    explained_variance | 0.827    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.0197  |
# |    value_loss         | 0.0814   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 466      |
# |    ep_rew_mean        | 5.53     |
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 3500     |
# |    time_elapsed       | 264      |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -0.0827  |
# |    explained_variance | 0.253    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -0.0144  |
# |    value_loss         | 0.539    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 472      |
# |    ep_rew_mean        | 5.77     |
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 3600     |
# |    time_elapsed       | 271      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -0.35    |
# |    explained_variance | 0.94     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.0132   |
# |    value_loss         | 0.0476   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 482      |
# |    ep_rew_mean        | 5.95     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 3700     |
# |    time_elapsed       | 278      |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -0.501   |
# |    explained_variance | 0.513    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.0682  |
# |    value_loss         | 0.148    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 480      |
# |    ep_rew_mean        | 5.9      |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 3800     |
# |    time_elapsed       | 286      |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -0.719   |
# |    explained_variance | 0.675    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.0176  |
# |    value_loss         | 0.0806   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 481      |
# |    ep_rew_mean        | 5.94     |
# | time/                 |          |
# |    fps                | 265      |
# |    iterations         | 3900     |
# |    time_elapsed       | 293      |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -0.45    |
# |    explained_variance | 0.899    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.0126   |
# |    value_loss         | 0.0335   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 497      |
# |    ep_rew_mean        | 6.2      |
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 4000     |
# |    time_elapsed       | 300      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -0.646   |
# |    explained_variance | 0.425    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.243   |
# |    value_loss         | 0.23     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 500      |
# |    ep_rew_mean        | 6.31     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 4100     |
# |    time_elapsed       | 306      |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -0.382   |
# |    explained_variance | 0.529    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.0547  |
# |    value_loss         | 0.169    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 509      |
# |    ep_rew_mean        | 6.44     |
# | time/                 |          |
# |    fps                | 267      |
# |    iterations         | 4200     |
# |    time_elapsed       | 313      |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -0.71    |
# |    explained_variance | -0.439   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.162    |
# |    value_loss         | 0.471    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 500      |
# |    ep_rew_mean        | 6.41     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 4300     |
# |    time_elapsed       | 320      |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -0.311   |
# |    explained_variance | 0.75     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.00442  |
# |    value_loss         | 0.427    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 509      |
# |    ep_rew_mean        | 6.58     |
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 4400     |
# |    time_elapsed       | 327      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -0.367   |
# |    explained_variance | 0.757    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.153    |
# |    value_loss         | 0.184    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 519      |
# |    ep_rew_mean        | 6.79     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 4500     |
# |    time_elapsed       | 334      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.503   |
# |    explained_variance | 0.905    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.109   |
# |    value_loss         | 0.0572   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 529      |
# |    ep_rew_mean        | 7.01     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 4600     |
# |    time_elapsed       | 341      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.456   |
# |    explained_variance | 0.727    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.187    |
# |    value_loss         | 0.0725   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 526      |
# |    ep_rew_mean        | 6.88     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 4700     |
# |    time_elapsed       | 347      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -0.376   |
# |    explained_variance | 0.786    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.328    |
# |    value_loss         | 0.249    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 529      |
# |    ep_rew_mean        | 6.9      |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 4800     |
# |    time_elapsed       | 354      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -0.475   |
# |    explained_variance | 0.957    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.0397  |
# |    value_loss         | 0.0623   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 532      |
# |    ep_rew_mean        | 6.79     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 4900     |
# |    time_elapsed       | 361      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -0.488   |
# |    explained_variance | 0.453    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.0907   |
# |    value_loss         | 0.211    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 536      |
# |    ep_rew_mean        | 6.86     |
# | time/                 |          |
# |    fps                | 271      |
# |    iterations         | 5000     |
# |    time_elapsed       | 368      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -0.489   |
# |    explained_variance | 0.561    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.00818 |
# |    value_loss         | 0.228    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 538      |
# |    ep_rew_mean        | 6.99     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 5100     |
# |    time_elapsed       | 374      |
# |    total_timesteps    | 102000   |
# | train/                |          |
# |    entropy_loss       | -0.372   |
# |    explained_variance | 0.945    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.0581  |
# |    value_loss         | 0.048    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 543      |
# |    ep_rew_mean        | 7.06     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 5200     |
# |    time_elapsed       | 381      |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -0.769   |
# |    explained_variance | 0.404    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -0.0495  |
# |    value_loss         | 0.132    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 555      |
# |    ep_rew_mean        | 7.3      |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 5300     |
# |    time_elapsed       | 388      |
# |    total_timesteps    | 106000   |
# | train/                |          |
# |    entropy_loss       | -0.544   |
# |    explained_variance | 0.591    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.102   |
# |    value_loss         | 0.206    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 545      |
# |    ep_rew_mean        | 7.12     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 5400     |
# |    time_elapsed       | 395      |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -0.717   |
# |    explained_variance | 0.675    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.0068   |
# |    value_loss         | 0.0893   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 529      |
# |    ep_rew_mean        | 6.82     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 5500     |
# |    time_elapsed       | 402      |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -0.814   |
# |    explained_variance | 0.928    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.00319  |
# |    value_loss         | 0.0895   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 532      |
# |    ep_rew_mean        | 6.85     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 5600     |
# |    time_elapsed       | 409      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -0.704   |
# |    explained_variance | 0.949    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.00406 |
# |    value_loss         | 0.0137   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 528      |
# |    ep_rew_mean        | 6.76     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 5700     |
# |    time_elapsed       | 416      |
# |    total_timesteps    | 114000   |
# | train/                |          |
# |    entropy_loss       | -0.472   |
# |    explained_variance | 0.923    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.0964   |
# |    value_loss         | 0.0947   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 532      |
# |    ep_rew_mean        | 6.89     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 5800     |
# |    time_elapsed       | 424      |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -0.402   |
# |    explained_variance | 0.698    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.0174   |
# |    value_loss         | 0.102    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 532      |
# |    ep_rew_mean        | 6.91     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 5900     |
# |    time_elapsed       | 431      |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -0.739   |
# |    explained_variance | 0.866    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.225    |
# |    value_loss         | 0.272    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 547      |
# |    ep_rew_mean        | 7.26     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 6000     |
# |    time_elapsed       | 438      |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -0.232   |
# |    explained_variance | 0.906    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -0.0411  |
# |    value_loss         | 0.155    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 556      |
# |    ep_rew_mean        | 7.47     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 6100     |
# |    time_elapsed       | 446      |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -0.433   |
# |    explained_variance | 0.816    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.0624  |
# |    value_loss         | 0.1      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 545      |
# |    ep_rew_mean        | 7.23     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 6200     |
# |    time_elapsed       | 454      |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -0.386   |
# |    explained_variance | 0.859    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.0303  |
# |    value_loss         | 0.0734   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 563      |
# |    ep_rew_mean        | 7.61     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 6300     |
# |    time_elapsed       | 461      |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -0.431   |
# |    explained_variance | -0.0695  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.13     |
# |    value_loss         | 0.172    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 569      |
# |    ep_rew_mean        | 7.72     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 6400     |
# |    time_elapsed       | 468      |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -0.237   |
# |    explained_variance | 0.748    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.0735  |
# |    value_loss         | 0.149    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 576      |
# |    ep_rew_mean        | 7.87     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 6500     |
# |    time_elapsed       | 476      |
# |    total_timesteps    | 130000   |
# | train/                |          |
# |    entropy_loss       | -0.22    |
# |    explained_variance | 0.894    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.0343  |
# |    value_loss         | 0.0583   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 577      |
# |    ep_rew_mean        | 7.96     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 6600     |
# |    time_elapsed       | 483      |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -0.32    |
# |    explained_variance | 0.114    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.0311  |
# |    value_loss         | 0.13     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 574      |
# |    ep_rew_mean        | 7.95     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 6700     |
# |    time_elapsed       | 490      |
# |    total_timesteps    | 134000   |
# | train/                |          |
# |    entropy_loss       | -0.256   |
# |    explained_variance | 0.956    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.12     |
# |    value_loss         | 0.131    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 583      |
# |    ep_rew_mean        | 8.16     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 6800     |
# |    time_elapsed       | 497      |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -0.414   |
# |    explained_variance | 0.873    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.219    |
# |    value_loss         | 0.219    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 585      |
# |    ep_rew_mean        | 8.26     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 6900     |
# |    time_elapsed       | 504      |
# |    total_timesteps    | 138000   |
# | train/                |          |
# |    entropy_loss       | -0.0721  |
# |    explained_variance | 0.928    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -0.00379 |
# |    value_loss         | 0.0347   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 576      |
# |    ep_rew_mean        | 8.06     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 7000     |
# |    time_elapsed       | 511      |
# |    total_timesteps    | 140000   |
# | train/                |          |
# |    entropy_loss       | -0.0714  |
# |    explained_variance | 0.904    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -0.00502 |
# |    value_loss         | 0.084    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 573      |
# |    ep_rew_mean        | 7.98     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 7100     |
# |    time_elapsed       | 519      |
# |    total_timesteps    | 142000   |
# | train/                |          |
# |    entropy_loss       | -0.177   |
# |    explained_variance | 0.754    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | 0.114    |
# |    value_loss         | 0.287    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 560      |
# |    ep_rew_mean        | 7.52     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 7200     |
# |    time_elapsed       | 526      |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -0.218   |
# |    explained_variance | 0.73     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | -0.0113  |
# |    value_loss         | 0.183    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 572      |
# |    ep_rew_mean        | 7.72     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 7300     |
# |    time_elapsed       | 534      |
# |    total_timesteps    | 146000   |
# | train/                |          |
# |    entropy_loss       | -0.407   |
# |    explained_variance | 0.235    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | -0.12    |
# |    value_loss         | 0.208    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 573      |
# |    ep_rew_mean        | 7.8      |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 7400     |
# |    time_elapsed       | 541      |
# |    total_timesteps    | 148000   |
# | train/                |          |
# |    entropy_loss       | -0.154   |
# |    explained_variance | 0.825    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | -0.0115  |
# |    value_loss         | 0.28     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 572      |
# |    ep_rew_mean        | 7.66     |
# | time/                 |          |
# |    fps                | 273      |
# |    iterations         | 7500     |
# |    time_elapsed       | 549      |
# |    total_timesteps    | 150000   |
# | train/                |          |
# |    entropy_loss       | -0.224   |
# |    explained_variance | 0.431    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | -0.109   |
# |    value_loss         | 0.462    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 581      |
# |    ep_rew_mean        | 7.91     |
# | time/                 |          |
# |    fps                | 272      |
# |    iterations         | 7600     |
# |    time_elapsed       | 556      |
# |    total_timesteps    | 152000   |
# | train/                |          |
# |    entropy_loss       | -0.143   |
# |    explained_variance | 0.855    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | -0.0156  |
# |    value_loss         | 0.114    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 580      |
# ...
# |    entropy_loss       | -0.081   |
# |    explained_variance | 0.739    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97499    |
# |    policy_loss        | 0.0109   |
# |    value_loss         | 0.0791   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 883      |
# |    ep_rew_mean        | 17       |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 97600    |
# |    time_elapsed       | 7245     |
# |    total_timesteps    | 1952000  |
# | train/                |          |
# |    entropy_loss       | -0.182   |
# |    explained_variance | 0.695    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97599    |
# |    policy_loss        | -0.0356  |
# |    value_loss         | 0.101    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 879      |
# |    ep_rew_mean        | 16.9     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 97700    |
# |    time_elapsed       | 7251     |
# |    total_timesteps    | 1954000  |
# | train/                |          |
# |    entropy_loss       | -0.156   |
# |    explained_variance | 0.441    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97699    |
# |    policy_loss        | 0.152    |
# |    value_loss         | 1.03     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 872      |
# |    ep_rew_mean        | 16.6     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 97800    |
# |    time_elapsed       | 7258     |
# |    total_timesteps    | 1956000  |
# | train/                |          |
# |    entropy_loss       | -0.0842  |
# |    explained_variance | 0.919    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97799    |
# |    policy_loss        | 0.0185   |
# |    value_loss         | 0.202    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 872      |
# |    ep_rew_mean        | 16.7     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 97900    |
# |    time_elapsed       | 7264     |
# |    total_timesteps    | 1958000  |
# | train/                |          |
# |    entropy_loss       | -0.162   |
# |    explained_variance | 0.172    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97899    |
# |    policy_loss        | -0.227   |
# |    value_loss         | 1.21     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 859      |
# |    ep_rew_mean        | 16.1     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 98000    |
# |    time_elapsed       | 7270     |
# |    total_timesteps    | 1960000  |
# | train/                |          |
# |    entropy_loss       | -0.138   |
# |    explained_variance | 0.0766   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 97999    |
# |    policy_loss        | 0.0179   |
# |    value_loss         | 0.0871   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 862      |
# |    ep_rew_mean        | 16.2     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 98100    |
# |    time_elapsed       | 7276     |
# |    total_timesteps    | 1962000  |
# | train/                |          |
# |    entropy_loss       | -0.154   |
# |    explained_variance | 0.689    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98099    |
# |    policy_loss        | 0.041    |
# |    value_loss         | 0.16     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 873      |
# |    ep_rew_mean        | 16.6     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 98200    |
# |    time_elapsed       | 7283     |
# |    total_timesteps    | 1964000  |
# | train/                |          |
# |    entropy_loss       | -0.117   |
# |    explained_variance | 0.777    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98199    |
# |    policy_loss        | -0.0226  |
# |    value_loss         | 0.458    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 875      |
# |    ep_rew_mean        | 16.9     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 98300    |
# |    time_elapsed       | 7289     |
# |    total_timesteps    | 1966000  |
# | train/                |          |
# |    entropy_loss       | -0.229   |
# |    explained_variance | 0.643    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98299    |
# |    policy_loss        | -0.0642  |
# |    value_loss         | 1.04     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 873      |
# |    ep_rew_mean        | 16.9     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 98400    |
# |    time_elapsed       | 7295     |
# |    total_timesteps    | 1968000  |
# | train/                |          |
# |    entropy_loss       | -0.179   |
# |    explained_variance | -4.61    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98399    |
# |    policy_loss        | 0.0504   |
# |    value_loss         | 0.41     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 841      |
# |    ep_rew_mean        | 15.9     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 98500    |
# |    time_elapsed       | 7301     |
# |    total_timesteps    | 1970000  |
# | train/                |          |
# |    entropy_loss       | -0.142   |
# |    explained_variance | 0.725    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98499    |
# |    policy_loss        | -0.165   |
# |    value_loss         | 0.754    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 846      |
# |    ep_rew_mean        | 16.1     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 98600    |
# |    time_elapsed       | 7307     |
# |    total_timesteps    | 1972000  |
# | train/                |          |
# |    entropy_loss       | -0.17    |
# |    explained_variance | 0.736    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98599    |
# |    policy_loss        | 0.0276   |
# |    value_loss         | 0.084    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 841      |
# |    ep_rew_mean        | 15.8     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 98700    |
# |    time_elapsed       | 7313     |
# |    total_timesteps    | 1974000  |
# | train/                |          |
# |    entropy_loss       | -0.188   |
# |    explained_variance | 0.879    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98699    |
# |    policy_loss        | 0.00977  |
# |    value_loss         | 0.0512   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 820      |
# |    ep_rew_mean        | 15.3     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 98800    |
# |    time_elapsed       | 7320     |
# |    total_timesteps    | 1976000  |
# | train/                |          |
# |    entropy_loss       | -0.0423  |
# |    explained_variance | 0.651    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98799    |
# |    policy_loss        | -0.0123  |
# |    value_loss         | 0.839    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 815      |
# |    ep_rew_mean        | 15.1     |
# | time/                 |          |
# |    fps                | 269      |
# |    iterations         | 98900    |
# |    time_elapsed       | 7326     |
# |    total_timesteps    | 1978000  |
# | train/                |          |
# |    entropy_loss       | -0.127   |
# |    explained_variance | 0.778    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98899    |
# |    policy_loss        | 0.0163   |
# |    value_loss         | 0.16     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 826      |
# |    ep_rew_mean        | 15.3     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 99000    |
# |    time_elapsed       | 7333     |
# |    total_timesteps    | 1980000  |
# | train/                |          |
# |    entropy_loss       | -0.089   |
# |    explained_variance | 0.793    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 98999    |
# |    policy_loss        | -0.0232  |
# |    value_loss         | 0.0313   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 821      |
# |    ep_rew_mean        | 15.2     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 99100    |
# |    time_elapsed       | 7339     |
# |    total_timesteps    | 1982000  |
# | train/                |          |
# |    entropy_loss       | -0.0556  |
# |    explained_variance | 0.631    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99099    |
# |    policy_loss        | -0.00648 |
# |    value_loss         | 0.747    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 826      |
# |    ep_rew_mean        | 15.4     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 99200    |
# |    time_elapsed       | 7345     |
# |    total_timesteps    | 1984000  |
# | train/                |          |
# |    entropy_loss       | -0.204   |
# |    explained_variance | 0.339    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99199    |
# |    policy_loss        | 0.00658  |
# |    value_loss         | 0.234    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 829      |
# |    ep_rew_mean        | 15.7     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 99300    |
# |    time_elapsed       | 7352     |
# |    total_timesteps    | 1986000  |
# | train/                |          |
# |    entropy_loss       | -0.192   |
# |    explained_variance | 0.82     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99299    |
# |    policy_loss        | 0.0716   |
# |    value_loss         | 0.219    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 832      |
# |    ep_rew_mean        | 15.8     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 99400    |
# |    time_elapsed       | 7358     |
# |    total_timesteps    | 1988000  |
# | train/                |          |
# |    entropy_loss       | -0.158   |
# |    explained_variance | 0.742    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99399    |
# |    policy_loss        | 0.0607   |
# |    value_loss         | 0.511    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 868      |
# |    ep_rew_mean        | 16.8     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 99500    |
# |    time_elapsed       | 7365     |
# |    total_timesteps    | 1990000  |
# | train/                |          |
# |    entropy_loss       | -0.216   |
# |    explained_variance | 0.597    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99499    |
# |    policy_loss        | -0.0884  |
# |    value_loss         | 0.93     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 888      |
# |    ep_rew_mean        | 17.5     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 99600    |
# |    time_elapsed       | 7371     |
# |    total_timesteps    | 1992000  |
# | train/                |          |
# |    entropy_loss       | -0.237   |
# |    explained_variance | -0.0326  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99599    |
# |    policy_loss        | -0.0378  |
# |    value_loss         | 0.2      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 883      |
# |    ep_rew_mean        | 17.4     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 99700    |
# |    time_elapsed       | 7377     |
# |    total_timesteps    | 1994000  |
# | train/                |          |
# |    entropy_loss       | -0.168   |
# |    explained_variance | 0.337    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99699    |
# |    policy_loss        | -0.00174 |
# |    value_loss         | 0.959    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 898      |
# |    ep_rew_mean        | 17.8     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 99800    |
# |    time_elapsed       | 7384     |
# |    total_timesteps    | 1996000  |
# | train/                |          |
# |    entropy_loss       | -0.15    |
# |    explained_variance | 0.88     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99799    |
# |    policy_loss        | 0.0126   |
# |    value_loss         | 0.0298   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 922      |
# |    ep_rew_mean        | 18.4     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 99900    |
# |    time_elapsed       | 7390     |
# |    total_timesteps    | 1998000  |
# | train/                |          |
# |    entropy_loss       | -0.136   |
# |    explained_variance | 0.817    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99899    |
# |    policy_loss        | 0.0124   |
# |    value_loss         | 0.0228   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 917      |
# |    ep_rew_mean        | 18.4     |
# | time/                 |          |
# |    fps                | 270      |
# |    iterations         | 100000   |
# |    time_elapsed       | 7397     |
# |    total_timesteps    | 2000000  |
# | train/                |          |
# |    entropy_loss       | -0.149   |
# |    explained_variance | 0.974    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99999    |
# |    policy_loss        | 0.0222   |
# |    value_loss         | 0.024    |
# ------------------------------------

# %% [markdown]
# # 4. Save and Reload Model

# %%
a2c_path = os.path.join('Training', 'Saved Models', 'A2C_model')

# %%
model.save(a2c_path)

# %%
del model

# %%
env = make_atari_env('Breakout-v0', n_envs=1, seed=0)
env = VecFrameStack(env, n_stack=4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-1f1e6031fde2> in <module>
# ----> 1 env = make_atari_env('Breakout-v0', n_envs=1, seed=0, render_mode='human')
#       2 env = VecFrameStack(env, n_stack=4)
#
# TypeError: make_atari_env() got an unexpected keyword argument 'render_mode'

# %%
model = A2C.load(a2c_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# # 5. Evaluate and Test

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# (10.7, 3.8223029707232783)

# %%
import time

obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render(mode='human')
    time.sleep(0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-9056582f0af4> in <module>
#       6     obs, rewards, dones, info = env.step(action)
#       7     env.render(mode='human')
# ----> 8     time.sleep(0.1)
#
# KeyboardInterrupt:

# %%
env.close()
